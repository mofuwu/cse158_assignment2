# %%
import json
from matplotlib import pyplot as plt
from collections import defaultdict
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import numpy
import random
import gzip
import math
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
from collections import Counter

# %%
f = gzip.open("cleaned_dataset.json.gz")
dataset = []
for l in f:
    dataset.append(json.loads(l))
dataset = dataset[0]

# %%
dataset[0]
# Out:
# {'fit': 'fit',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': 137,
#  'rating': 10,
#  'rented for': 'vacation',
#  'review_text': "An adorable romper! Belt and zipper were a little hard to navigate in a full day of wear/bathroom use, but that's to be expected. Wish it had pockets, but other than that-- absolutely perfect! I got a million compliments.",
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': 68,
#  'size': 14,
#  'age': 28,
#  'fit_numeric': 0}

# %%
dataTest = dataset[117105:]
dataTrain = dataset[:117105]

print(len(dataTrain))
print(len(dataTest))
# Out:
# 117105
# 29276

# %%
# one hot encoding body type

unique_body_types = list(set(d['body type'] for d in dataTrain))
body_type_to_onehot = {bt: [1 if i == idx else 0 for i in range(len(unique_body_types))] for idx, bt in enumerate(unique_body_types)}

# %%
# using the frequency of each item id as input

item_id_counts = Counter(d['item_id'] for d in dataTrain)
total_items = sum(item_id_counts.values())

item_id_to_frequency = {item: count / total_items for item, count in item_id_counts.items()}

# %%
def feat1(datum):
    
    onehot_body_type = body_type_to_onehot.get(datum['body type'], [0]*len(unique_body_types))
    
    frequency_item_id = item_id_to_frequency.get(datum['item_id'], 0)
    
    height = datum['height']
    weight = datum['weight']
    size = datum['size']
    
    return [1] + [height] + [weight] + [size] + onehot_body_type + [frequency_item_id]

# %%
X_train = [feat1(d) for d in dataTrain]
y_train = [d['fit_numeric'] for d in dataTrain]

X_test = [feat1(d) for d in dataTest]
y_test = [d['fit_numeric'] for d in dataTest]

# %%
model = LogisticRegression(max_iter=500, solver = 'saga', verbose=1)
model.fit(X_train, y_train)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.06870177
# Epoch 3, change: 0.06154894
# Epoch 4, change: 0.05924740
# Epoch 5, change: 0.05026000
# Epoch 6, change: 0.04726574
# Epoch 7, change: 0.04443500
# Epoch 8, change: 0.04199048
# Epoch 9, change: 0.03901402
# Epoch 10, change: 0.03666024
# Epoch 11, change: 0.03462586
# Epoch 12, change: 0.03250560
# Epoch 13, change: 0.03152542
# Epoch 14, change: 0.03064629
# Epoch 15, change: 0.02981865
# Epoch 16, change: 0.02899516
# Epoch 17, change: 0.02819683
# Epoch 18, change: 0.02742270
# Epoch 19, change: 0.02667889
# Epoch 20, change: 0.02594178
# Epoch 21, change: 0.02521656
# Epoch 22, change: 0.02453319
# Epoch 23, change: 0.02384364
# Epoch 24, change: 0.02319355
# Epoch 25, change: 0.02252822
# Epoch 26, change: 0.02192325
# Epoch 27, change: 0.02131147
# Epoch 28, change: 0.02072585
# Epoch 29, change: 0.02013973
# Epoch 30, change: 0.01957439
# Epoch 31, change: 0.01902982
# Epoch 32, change: 0.01849817
# Epoch 33, change: 0.01781030
# Epoch 34, change: 0.01712500
# Epoch 35, change: 0.01649963
# Epoch 36, change: 0.01587907
# Epoch 37, change: 0.01528522
# Epoch 38, change: 0.01473559
# Epoch 39, change: 0.01420055
# Epoch 40, change: 0.01363256
# Epoch 41, change: 0.01307080
# Epoch 42, change: 0.01254108
# Epoch 43, change: 0.01204546
# Epoch 44, change: 0.01157477
# Epoch 45, change: 0.01110158
# Epoch 46, change: 0.01066988
# Epoch 47, change: 0.01026645
# Epoch 48, change: 0.00987529
# Epoch 49, change: 0.00950054
# Epoch 50, change: 0.00913539
# Epoch 51, change: 0.00894879
# Epoch 52, change: 0.00879712
# Epoch 53, change: 0.00865645
# Epoch 54, change: 0.00851413
# Epoch 55, change: 0.00838103
# Epoch 56, change: 0.00825278
# Epoch 57, change: 0.00812746
# Epoch 58, change: 0.00800726
# Epoch 59, change: 0.00788302
# Epoch 60, change: 0.00777194
# Epoch 61, change: 0.00766049
# Epoch 62, change: 0.00755169
# Epoch 63, change: 0.00744693
# Epoch 64, change: 0.00734682
# Epoch 65, change: 0.00724367
# Epoch 66, change: 0.00714575
# Epoch 67, change: 0.00704991
# Epoch 68, change: 0.00695609
# Epoch 69, change: 0.00686769
# Epoch 70, change: 0.00677619
# Epoch 71, change: 0.00669481
# Epoch 72, change: 0.00660681
# Epoch 73, change: 0.00652495
# Epoch 74, change: 0.00644393
# Epoch 75, change: 0.00636426
# Epoch 76, change: 0.00628735
# Epoch 77, change: 0.00621169
# Epoch 78, change: 0.00613856
# Epoch 79, change: 0.00606830
# Epoch 80, change: 0.00599112
# Epoch 81, change: 0.00592478
# Epoch 82, change: 0.00585453
# Epoch 83, change: 0.00578804
# Epoch 84, change: 0.00572356
# Epoch 85, change: 0.00566033
# Epoch 86, change: 0.00559404
# Epoch 87, change: 0.00553178
# Epoch 88, change: 0.00547015
# Epoch 89, change: 0.00541174
# Epoch 90, change: 0.00535216
# Epoch 91, change: 0.00529463
# Epoch 92, change: 0.00523669
# Epoch 93, change: 0.00517983
# Epoch 94, change: 0.00512327
# Epoch 95, change: 0.00507053
# Epoch 96, change: 0.00501585
# Epoch 97, change: 0.00496497
# Epoch 98, change: 0.00491150
# Epoch 99, change: 0.00486076
# Epoch 100, change: 0.00480849
# Epoch 101, change: 0.00475879
# Epoch 102, change: 0.00471042
# Epoch 103, change: 0.00466178
# Epoch 104, change: 0.00461443
# Epoch 105, change: 0.00456635
# Epoch 106, change: 0.00451939
# Epoch 107, change: 0.00447279
# Epoch 108, change: 0.00442899
# Epoch 109, change: 0.00438980
# Epoch 110, change: 0.00434849
# Epoch 111, change: 0.00430814
# Epoch 112, change: 0.00426529
# Epoch 113, change: 0.00422061
# Epoch 114, change: 0.00417711
# Epoch 115, change: 0.00413591
# Epoch 116, change: 0.00409546
# Epoch 117, change: 0.00405394
# Epoch 118, change: 0.00401404
# Epoch 119, change: 0.00397379
# Epoch 120, change: 0.00393381
# Epoch 121, change: 0.00389617
# Epoch 122, change: 0.00385812
# Epoch 123, change: 0.00381954
# Epoch 124, change: 0.00378175
# Epoch 125, change: 0.00374499
# Epoch 126, change: 0.00370897
# Epoch 127, change: 0.00367315
# Epoch 128, change: 0.00363674
# Epoch 129, change: 0.00360091
# Epoch 130, change: 0.00356671
# Epoch 131, change: 0.00353291
# Epoch 132, change: 0.00349831
# Epoch 133, change: 0.00346398
# Epoch 134, change: 0.00343023
# Epoch 135, change: 0.00339677
# Epoch 136, change: 0.00336547
# Epoch 137, change: 0.00333195
# Epoch 138, change: 0.00332085
# Epoch 139, change: 0.00331048
# Epoch 140, change: 0.00330018
# Epoch 141, change: 0.00328989
# Epoch 142, change: 0.00327966
# Epoch 143, change: 0.00326956
# Epoch 144, change: 0.00325982
# Epoch 145, change: 0.00324974
# Epoch 146, change: 0.00323997
# Epoch 147, change: 0.00323023
# Epoch 148, change: 0.00322051
# Epoch 149, change: 0.00321097
# Epoch 150, change: 0.00320133
# Epoch 151, change: 0.00319194
# Epoch 152, change: 0.00318256
# Epoch 153, change: 0.00317318
# Epoch 154, change: 0.00316395
# Epoch 155, change: 0.00315474
# Epoch 156, change: 0.00314566
# Epoch 157, change: 0.00313662
# Epoch 158, change: 0.00312760
# Epoch 159, change: 0.00311873
# Epoch 160, change: 0.00310983
# Epoch 161, change: 0.00310092
# Epoch 162, change: 0.00309219
# Epoch 163, change: 0.00308353
# Epoch 164, change: 0.00307493
# Epoch 165, change: 0.00306635
# Epoch 166, change: 0.00305779
# Epoch 167, change: 0.00304939
# Epoch 168, change: 0.00304092
# Epoch 169, change: 0.00303257
# Epoch 170, change: 0.00302421
# Epoch 171, change: 0.00301595
# Epoch 172, change: 0.00300771
# Epoch 173, change: 0.00299957
# Epoch 174, change: 0.00299141
# Epoch 175, change: 0.00298337
# Epoch 176, change: 0.00297538
# Epoch 177, change: 0.00296731
# Epoch 178, change: 0.00295943
# Epoch 179, change: 0.00295156
# Epoch 180, change: 0.00294364
# Epoch 181, change: 0.00293591
# Epoch 182, change: 0.00292819
# Epoch 183, change: 0.00292053
# Epoch 184, change: 0.00291280
# Epoch 185, change: 0.00290524
# Epoch 186, change: 0.00289757
# Epoch 187, change: 0.00289003
# Epoch 188, change: 0.00288252
# Epoch 189, change: 0.00287502
# Epoch 190, change: 0.00286760
# Epoch 191, change: 0.00286020
# Epoch 192, change: 0.00285281
# Epoch 193, change: 0.00284544
# Epoch 194, change: 0.00283815
# Epoch 195, change: 0.00283106
# Epoch 196, change: 0.00282377
# Epoch 197, change: 0.00281660
# Epoch 198, change: 0.00280951
# Epoch 199, change: 0.00280239
# Epoch 200, change: 0.00279526
# Epoch 201, change: 0.00278822
# Epoch 202, change: 0.00278125
# Epoch 203, change: 0.00277418
# Epoch 204, change: 0.00276737
# Epoch 205, change: 0.00276044
# Epoch 206, change: 0.00275357
# Epoch 207, change: 0.00274671
# Epoch 208, change: 0.00273993
# Epoch 209, change: 0.00273311
# Epoch 210, change: 0.00272629
# Epoch 211, change: 0.00271959
# Epoch 212, change: 0.00271294
# Epoch 213, change: 0.00270628
# Epoch 214, change: 0.00269961
# Epoch 215, change: 0.00269306
# Epoch 216, change: 0.00268647
# Epoch 217, change: 0.00267981
# Epoch 218, change: 0.00267352
# Epoch 219, change: 0.00266684
# Epoch 220, change: 0.00266045
# Epoch 221, change: 0.00265401
# Epoch 222, change: 0.00264755
# Epoch 223, change: 0.00264122
# Epoch 224, change: 0.00263480
# Epoch 225, change: 0.00262846
# Epoch 226, change: 0.00262217
# Epoch 227, change: 0.00261590
# Epoch 228, change: 0.00260958
# Epoch 229, change: 0.00260342
# Epoch 230, change: 0.00259719
# Epoch 231, change: 0.00259107
# Epoch 232, change: 0.00258485
# Epoch 233, change: 0.00257868
# Epoch 234, change: 0.00257251
# Epoch 235, change: 0.00256647
# Epoch 236, change: 0.00256045
# Epoch 237, change: 0.00255436
# Epoch 238, change: 0.00254836
# Epoch 239, change: 0.00254242
# Epoch 240, change: 0.00253641
# Epoch 241, change: 0.00253049
# Epoch 242, change: 0.00252453
# Epoch 243, change: 0.00251858
# Epoch 244, change: 0.00251275
# Epoch 245, change: 0.00250694
# Epoch 246, change: 0.00250101
# Epoch 247, change: 0.00249521
# Epoch 248, change: 0.00248946
# Epoch 249, change: 0.00248313
# Epoch 250, change: 0.00247543
# Epoch 251, change: 0.00246792
# Epoch 252, change: 0.00246042
# Epoch 253, change: 0.00245296
# Epoch 254, change: 0.00244556
# Epoch 255, change: 0.00243818
# Epoch 256, change: 0.00243087
# Epoch 257, change: 0.00242355
# Epoch 258, change: 0.00241629
# Epoch 259, change: 0.00240916
# Epoch 260, change: 0.00240198
# Epoch 261, change: 0.00239494
# Epoch 262, change: 0.00238791
# Epoch 263, change: 0.00238093
# Epoch 264, change: 0.00237386
# Epoch 265, change: 0.00236708
# Epoch 266, change: 0.00236012
# Epoch 267, change: 0.00235335
# Epoch 268, change: 0.00234659
# Epoch 269, change: 0.00233979
# Epoch 270, change: 0.00233313
# Epoch 271, change: 0.00232648
# Epoch 272, change: 0.00231987
# Epoch 273, change: 0.00231324
# Epoch 274, change: 0.00230677
# Epoch 275, change: 0.00230022
# Epoch 276, change: 0.00229376
# Epoch 277, change: 0.00228789
# Epoch 278, change: 0.00228281
# Epoch 279, change: 0.00227773
# Epoch 280, change: 0.00227271
# Epoch 281, change: 0.00226774
# Epoch 282, change: 0.00226277
# Epoch 283, change: 0.00225782
# Epoch 284, change: 0.00225290
# Epoch 285, change: 0.00224802
# Epoch 286, change: 0.00224314
# Epoch 287, change: 0.00223835
# Epoch 288, change: 0.00223355
# Epoch 289, change: 0.00222882
# Epoch 290, change: 0.00222400
# Epoch 291, change: 0.00221931
# Epoch 292, change: 0.00221462
# Epoch 293, change: 0.00220999
# Epoch 294, change: 0.00220533
# Epoch 295, change: 0.00220073
# Epoch 296, change: 0.00219614
# Epoch 297, change: 0.00219156
# Epoch 298, change: 0.00218706
# Epoch 299, change: 0.00218255
# Epoch 300, change: 0.00217805
# Epoch 301, change: 0.00217360
# Epoch 302, change: 0.00216913
# Epoch 303, change: 0.00216476
# Epoch 304, change: 0.00216036
# Epoch 305, change: 0.00215598
# Epoch 306, change: 0.00215168
# Epoch 307, change: 0.00214738
# Epoch 308, change: 0.00214305
# Epoch 309, change: 0.00213876
# Epoch 310, change: 0.00213451
# Epoch 311, change: 0.00213034
# Epoch 312, change: 0.00212606
# Epoch 313, change: 0.00212186
# Epoch 314, change: 0.00211777
# Epoch 315, change: 0.00211362
# Epoch 316, change: 0.00210948
# Epoch 317, change: 0.00210535
# Epoch 318, change: 0.00210132
# Epoch 319, change: 0.00209724
# Epoch 320, change: 0.00209319
# Epoch 321, change: 0.00208919
# Epoch 322, change: 0.00208516
# Epoch 323, change: 0.00208116
# Epoch 324, change: 0.00207720
# Epoch 325, change: 0.00207329
# Epoch 326, change: 0.00206933
# Epoch 327, change: 0.00206545
# Epoch 328, change: 0.00206158
# Epoch 329, change: 0.00205774
# Epoch 330, change: 0.00205381
# Epoch 331, change: 0.00204999
# Epoch 332, change: 0.00204619
# Epoch 333, change: 0.00204238
# Epoch 334, change: 0.00203861
# Epoch 335, change: 0.00203484
# Epoch 336, change: 0.00203113
# Epoch 337, change: 0.00202736
# Epoch 338, change: 0.00202365
# Epoch 339, change: 0.00201997
# Epoch 340, change: 0.00201629
# Epoch 341, change: 0.00201261
# Epoch 342, change: 0.00200903
# Epoch 343, change: 0.00200532
# Epoch 344, change: 0.00200177
# Epoch 345, change: 0.00199817
# Epoch 346, change: 0.00199457
# Epoch 347, change: 0.00199100
# Epoch 348, change: 0.00198748
# Epoch 349, change: 0.00198387
# Epoch 350, change: 0.00198040
# Epoch 351, change: 0.00197686
# Epoch 352, change: 0.00197339
# Epoch 353, change: 0.00196989
# Epoch 354, change: 0.00196645
# Epoch 355, change: 0.00196297
# Epoch 356, change: 0.00195957
# Epoch 357, change: 0.00195614
# Epoch 358, change: 0.00195271
# Epoch 359, change: 0.00194933
# Epoch 360, change: 0.00194597
# Epoch 361, change: 0.00194258
# Epoch 362, change: 0.00193929
# Epoch 363, change: 0.00193589
# Epoch 364, change: 0.00193254
# Epoch 365, change: 0.00192930
# Epoch 366, change: 0.00192597
# Epoch 367, change: 0.00192272
# Epoch 368, change: 0.00191943
# Epoch 369, change: 0.00191617
# Epoch 370, change: 0.00191295
# Epoch 371, change: 0.00190966
# Epoch 372, change: 0.00190646
# Epoch 373, change: 0.00190324
# Epoch 374, change: 0.00190005
# Epoch 375, change: 0.00189691
# Epoch 376, change: 0.00189368
# Epoch 377, change: 0.00189056
# Epoch 378, change: 0.00188739
# Epoch 379, change: 0.00188429
# Epoch 380, change: 0.00188062
# Epoch 381, change: 0.00187483
# Epoch 382, change: 0.00186910
# Epoch 383, change: 0.00186332
# Epoch 384, change: 0.00185757
# Epoch 385, change: 0.00185191
# Epoch 386, change: 0.00184627
# Epoch 387, change: 0.00184066
# Epoch 388, change: 0.00183500
# Epoch 389, change: 0.00182948
# Epoch 390, change: 0.00182390
# Epoch 391, change: 0.00181842
# Epoch 392, change: 0.00181297
# Epoch 393, change: 0.00180748
# Epoch 394, change: 0.00180208
# Epoch 395, change: 0.00179665
# Epoch 396, change: 0.00179129
# Epoch 397, change: 0.00178591
# Epoch 398, change: 0.00178059
# Epoch 399, change: 0.00177535
# Epoch 400, change: 0.00177006
# Epoch 401, change: 0.00176484
# Epoch 402, change: 0.00175959
# Epoch 403, change: 0.00175443
# Epoch 404, change: 0.00174924
# Epoch 405, change: 0.00174411
# Epoch 406, change: 0.00173900
# Epoch 407, change: 0.00173392
# Epoch 408, change: 0.00172884
# Epoch 409, change: 0.00172384
# Epoch 410, change: 0.00171878
# Epoch 411, change: 0.00171382
# Epoch 412, change: 0.00170883
# Epoch 413, change: 0.00170393
# Epoch 414, change: 0.00169900
# Epoch 415, change: 0.00169410
# Epoch 416, change: 0.00168924
# Epoch 417, change: 0.00168439
# Epoch 418, change: 0.00167956
# Epoch 419, change: 0.00167476
# Epoch 420, change: 0.00167001
# Epoch 421, change: 0.00166525
# Epoch 422, change: 0.00166051
# Epoch 423, change: 0.00165581
# Epoch 424, change: 0.00165109
# Epoch 425, change: 0.00164645
# Epoch 426, change: 0.00164183
# Epoch 427, change: 0.00163721
# Epoch 428, change: 0.00163261
# Epoch 429, change: 0.00162802
# Epoch 430, change: 0.00162349
# Epoch 431, change: 0.00161896
# Epoch 432, change: 0.00161442
# Epoch 433, change: 0.00160993
# Epoch 434, change: 0.00160544
# Epoch 435, change: 0.00160105
# Epoch 436, change: 0.00159660
# Epoch 437, change: 0.00159219
# Epoch 438, change: 0.00158778
# Epoch 439, change: 0.00158345
# Epoch 440, change: 0.00157903
# Epoch 441, change: 0.00157477
# Epoch 442, change: 0.00157043
# Epoch 443, change: 0.00156616
# Epoch 444, change: 0.00156190
# Epoch 445, change: 0.00155763
# Epoch 446, change: 0.00155338
# Epoch 447, change: 0.00154918
# Epoch 448, change: 0.00154499
# Epoch 449, change: 0.00154084
# Epoch 450, change: 0.00153667
# Epoch 451, change: 0.00153251
# Epoch 452, change: 0.00152841
# Epoch 453, change: 0.00152429
# Epoch 454, change: 0.00152021
# Epoch 455, change: 0.00151615
# Epoch 456, change: 0.00151211
# Epoch 457, change: 0.00150807
# Epoch 458, change: 0.00150410
# Epoch 459, change: 0.00150008
# Epoch 460, change: 0.00149612
# Epoch 461, change: 0.00149214
# Epoch 462, change: 0.00148822
# Epoch 463, change: 0.00148426
# Epoch 464, change: 0.00148038
# Epoch 465, change: 0.00147649
# Epoch 466, change: 0.00147256
# Epoch 467, change: 0.00146872
# Epoch 468, change: 0.00146490
# Epoch 469, change: 0.00146109
# Epoch 470, change: 0.00145726
# Epoch 471, change: 0.00145348
# Epoch 472, change: 0.00144969
# Epoch 473, change: 0.00144596
# Epoch 474, change: 0.00144222
# Epoch 475, change: 0.00143847
# Epoch 476, change: 0.00143476
# Epoch 477, change: 0.00143110
# Epoch 478, change: 0.00142739
# Epoch 479, change: 0.00142374
# Epoch 480, change: 0.00142008
# Epoch 481, change: 0.00141644
# Epoch 482, change: 0.00141281
# Epoch 483, change: 0.00140923
# Epoch 484, change: 0.00140565
# Epoch 485, change: 0.00140208
# Epoch 486, change: 0.00139852
# Epoch 487, change: 0.00139497
# Epoch 488, change: 0.00139144
# Epoch 489, change: 0.00138789
# Epoch 490, change: 0.00138442
# Epoch 491, change: 0.00138094
# Epoch 492, change: 0.00137750
# Epoch 493, change: 0.00137402
# Epoch 494, change: 0.00137057
# Epoch 495, change: 0.00136713
# Epoch 496, change: 0.00136374
# Epoch 497, change: 0.00136035
# Epoch 498, change: 0.00135690
# Epoch 499, change: 0.00135357
# max_iter reached after 15 seconds
# Epoch 500, change: 0.00135019
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(max_iter=500, solver='saga', verbose=1)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy", train_accuracy)
print(f"Test Accuracy", test_accuracy)
# Out:
# Training Accuracy 0.7346569318133299
# Test Accuracy 0.7357904085257548
