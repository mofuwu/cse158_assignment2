# %%
import json
from matplotlib import pyplot as plt
from collections import defaultdict
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import numpy
import random
import gzip
import math
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
from collections import Counter

# %%
f = gzip.open("cleaned_dataset.json.gz")
dataset = []
for l in f:
    dataset.append(json.loads(l))
dataset = dataset[0]

# %%
dataset[0]
# Out:
# {'fit': 'fit',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': 137,
#  'rating': 10,
#  'rented for': 'vacation',
#  'review_text': "An adorable romper! Belt and zipper were a little hard to navigate in a full day of wear/bathroom use, but that's to be expected. Wish it had pockets, but other than that-- absolutely perfect! I got a million compliments.",
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': 68,
#  'size': 14,
#  'age': 28,
#  'fit_numeric': 0}

# %%
import sklearn
from sklearn.model_selection import train_test_split

dataTrain, dataTest = train_test_split(dataset, test_size= 0.2, random_state=42)

print(len(dataTrain))
print(len(dataTest))
# Out:
# 117104
# 29277

# %%
# one hot encoding body type

unique_body_types = list(set(d['body type'] for d in dataTrain))
body_type_to_onehot = {bt: [1 if i == idx else 0 for i in range(len(unique_body_types))] for idx, bt in enumerate(unique_body_types)}

# %%
# using the frequency of each item id as input

item_id_counts = Counter(d['item_id'] for d in dataTrain)
total_items = sum(item_id_counts.values())

item_id_to_frequency = {item: count / total_items for item, count in item_id_counts.items()}

# %%
def feat1(datum):
    
    onehot_body_type = body_type_to_onehot.get(datum['body type'], [0]*len(unique_body_types))
    
    frequency_item_id = item_id_to_frequency.get(datum['item_id'], 0)
    
    height = datum['height']
    weight = datum['weight']
    size = datum['size']
    
    return [1] + [height] + [weight] + [size] + onehot_body_type + [frequency_item_id]

# %%
X_train = [feat1(d) for d in dataTrain]
y_train = [d['fit_numeric'] for d in dataTrain]

X_test = [feat1(d) for d in dataTest]
y_test = [d['fit_numeric'] for d in dataTest]

# %%
model = LogisticRegression(max_iter=500, solver = 'saga', verbose=1)
model.fit(X_train, y_train)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.08188559
# Epoch 3, change: 0.05915669
# Epoch 4, change: 0.04740498
# Epoch 5, change: 0.04704948
# Epoch 6, change: 0.04411341
# Epoch 7, change: 0.04120418
# Epoch 8, change: 0.03875913
# Epoch 9, change: 0.03634364
# Epoch 10, change: 0.03384640
# Epoch 11, change: 0.03206968
# Epoch 12, change: 0.03122196
# Epoch 13, change: 0.03027993
# Epoch 14, change: 0.02941278
# Epoch 15, change: 0.02858526
# Epoch 16, change: 0.02773625
# Epoch 17, change: 0.02695197
# Epoch 18, change: 0.02617101
# Epoch 19, change: 0.02539001
# Epoch 20, change: 0.02465991
# Epoch 21, change: 0.02392798
# Epoch 22, change: 0.02324242
# Epoch 23, change: 0.02257550
# Epoch 24, change: 0.02190583
# Epoch 25, change: 0.02128039
# Epoch 26, change: 0.02065488
# Epoch 27, change: 0.02004769
# Epoch 28, change: 0.01946661
# Epoch 29, change: 0.01888221
# Epoch 30, change: 0.01834202
# Epoch 31, change: 0.01780334
# Epoch 32, change: 0.01729904
# Epoch 33, change: 0.01677432
# Epoch 34, change: 0.01626876
# Epoch 35, change: 0.01578808
# Epoch 36, change: 0.01520217
# Epoch 37, change: 0.01454096
# Epoch 38, change: 0.01392291
# Epoch 39, change: 0.01332845
# Epoch 40, change: 0.01277345
# Epoch 41, change: 0.01223822
# Epoch 42, change: 0.01174258
# Epoch 43, change: 0.01126214
# Epoch 44, change: 0.01080719
# Epoch 45, change: 0.01038968
# Epoch 46, change: 0.00997533
# Epoch 47, change: 0.00959039
# Epoch 48, change: 0.00932960
# Epoch 49, change: 0.00916199
# Epoch 50, change: 0.00900915
# Epoch 51, change: 0.00885856
# Epoch 52, change: 0.00871280
# Epoch 53, change: 0.00857130
# Epoch 54, change: 0.00843720
# Epoch 55, change: 0.00830622
# Epoch 56, change: 0.00818232
# Epoch 57, change: 0.00806006
# Epoch 58, change: 0.00793990
# Epoch 59, change: 0.00782197
# Epoch 60, change: 0.00771215
# Epoch 61, change: 0.00760238
# Epoch 62, change: 0.00749690
# Epoch 63, change: 0.00739716
# Epoch 64, change: 0.00729363
# Epoch 65, change: 0.00720479
# Epoch 66, change: 0.00710329
# Epoch 67, change: 0.00701595
# Epoch 68, change: 0.00691998
# Epoch 69, change: 0.00683525
# Epoch 70, change: 0.00675189
# Epoch 71, change: 0.00666853
# Epoch 72, change: 0.00658779
# Epoch 73, change: 0.00650650
# Epoch 74, change: 0.00643025
# Epoch 75, change: 0.00635563
# Epoch 76, change: 0.00628111
# Epoch 77, change: 0.00621050
# Epoch 78, change: 0.00613902
# Epoch 79, change: 0.00606791
# Epoch 80, change: 0.00599940
# Epoch 81, change: 0.00593274
# Epoch 82, change: 0.00587031
# Epoch 83, change: 0.00580471
# Epoch 84, change: 0.00574344
# Epoch 85, change: 0.00567933
# Epoch 86, change: 0.00561826
# Epoch 87, change: 0.00556128
# Epoch 88, change: 0.00550215
# Epoch 89, change: 0.00544312
# Epoch 90, change: 0.00539001
# Epoch 91, change: 0.00533483
# Epoch 92, change: 0.00528027
# Epoch 93, change: 0.00522681
# Epoch 94, change: 0.00517338
# Epoch 95, change: 0.00512339
# Epoch 96, change: 0.00507234
# Epoch 97, change: 0.00502346
# Epoch 98, change: 0.00497305
# Epoch 99, change: 0.00492544
# Epoch 100, change: 0.00487669
# Epoch 101, change: 0.00483179
# Epoch 102, change: 0.00478399
# Epoch 103, change: 0.00473558
# Epoch 104, change: 0.00469420
# Epoch 105, change: 0.00465041
# Epoch 106, change: 0.00460532
# Epoch 107, change: 0.00456408
# Epoch 108, change: 0.00451911
# Epoch 109, change: 0.00448026
# Epoch 110, change: 0.00443895
# Epoch 111, change: 0.00439558
# Epoch 112, change: 0.00435830
# Epoch 113, change: 0.00431718
# Epoch 114, change: 0.00427830
# Epoch 115, change: 0.00423955
# Epoch 116, change: 0.00420138
# Epoch 117, change: 0.00416376
# Epoch 118, change: 0.00412637
# Epoch 119, change: 0.00409005
# Epoch 120, change: 0.00405175
# Epoch 121, change: 0.00401796
# Epoch 122, change: 0.00398377
# Epoch 123, change: 0.00394697
# Epoch 124, change: 0.00391215
# Epoch 125, change: 0.00387855
# Epoch 126, change: 0.00384465
# Epoch 127, change: 0.00381193
# Epoch 128, change: 0.00377778
# Epoch 129, change: 0.00374689
# Epoch 130, change: 0.00371347
# Epoch 131, change: 0.00368110
# Epoch 132, change: 0.00365156
# Epoch 133, change: 0.00361891
# Epoch 134, change: 0.00358858
# Epoch 135, change: 0.00357765
# Epoch 136, change: 0.00357068
# Epoch 137, change: 0.00356382
# Epoch 138, change: 0.00355701
# Epoch 139, change: 0.00355033
# Epoch 140, change: 0.00354379
# Epoch 141, change: 0.00353712
# Epoch 142, change: 0.00353056
# Epoch 143, change: 0.00352400
# Epoch 144, change: 0.00351779
# Epoch 145, change: 0.00351146
# Epoch 146, change: 0.00350523
# Epoch 147, change: 0.00349906
# Epoch 148, change: 0.00349287
# Epoch 149, change: 0.00348676
# Epoch 150, change: 0.00348075
# Epoch 151, change: 0.00347477
# Epoch 152, change: 0.00346880
# Epoch 153, change: 0.00346297
# Epoch 154, change: 0.00345717
# Epoch 155, change: 0.00345133
# Epoch 156, change: 0.00344559
# Epoch 157, change: 0.00343997
# Epoch 158, change: 0.00343432
# Epoch 159, change: 0.00342871
# Epoch 160, change: 0.00342316
# Epoch 161, change: 0.00341761
# Epoch 162, change: 0.00341064
# Epoch 163, change: 0.00339458
# Epoch 164, change: 0.00337864
# Epoch 165, change: 0.00336300
# Epoch 166, change: 0.00334738
# Epoch 167, change: 0.00333206
# Epoch 168, change: 0.00331680
# Epoch 169, change: 0.00330184
# Epoch 170, change: 0.00328697
# Epoch 171, change: 0.00327222
# Epoch 172, change: 0.00325766
# Epoch 173, change: 0.00324322
# Epoch 174, change: 0.00322910
# Epoch 175, change: 0.00321487
# Epoch 176, change: 0.00320099
# Epoch 177, change: 0.00318713
# Epoch 178, change: 0.00317351
# Epoch 179, change: 0.00316001
# Epoch 180, change: 0.00314651
# Epoch 181, change: 0.00313325
# Epoch 182, change: 0.00312033
# Epoch 183, change: 0.00310724
# Epoch 184, change: 0.00309448
# Epoch 185, change: 0.00308161
# Epoch 186, change: 0.00306912
# Epoch 187, change: 0.00305655
# Epoch 188, change: 0.00304421
# Epoch 189, change: 0.00303198
# Epoch 190, change: 0.00301978
# Epoch 191, change: 0.00300786
# Epoch 192, change: 0.00299586
# Epoch 193, change: 0.00298419
# Epoch 194, change: 0.00297243
# Epoch 195, change: 0.00296080
# Epoch 196, change: 0.00294938
# Epoch 197, change: 0.00293806
# Epoch 198, change: 0.00292677
# Epoch 199, change: 0.00291565
# Epoch 200, change: 0.00290455
# Epoch 201, change: 0.00289366
# Epoch 202, change: 0.00288275
# Epoch 203, change: 0.00287191
# Epoch 204, change: 0.00286124
# Epoch 205, change: 0.00285072
# Epoch 206, change: 0.00284018
# Epoch 207, change: 0.00282980
# Epoch 208, change: 0.00281947
# Epoch 209, change: 0.00280923
# Epoch 210, change: 0.00279920
# Epoch 211, change: 0.00278900
# Epoch 212, change: 0.00277901
# Epoch 213, change: 0.00276920
# Epoch 214, change: 0.00275937
# Epoch 215, change: 0.00274967
# Epoch 216, change: 0.00274004
# Epoch 217, change: 0.00273043
# Epoch 218, change: 0.00272084
# Epoch 219, change: 0.00271152
# Epoch 220, change: 0.00270225
# Epoch 221, change: 0.00269291
# Epoch 222, change: 0.00268371
# Epoch 223, change: 0.00267450
# Epoch 224, change: 0.00266550
# Epoch 225, change: 0.00265655
# Epoch 226, change: 0.00264762
# Epoch 227, change: 0.00263878
# Epoch 228, change: 0.00262992
# Epoch 229, change: 0.00262126
# Epoch 230, change: 0.00261255
# Epoch 231, change: 0.00260404
# Epoch 232, change: 0.00259549
# Epoch 233, change: 0.00258701
# Epoch 234, change: 0.00257859
# Epoch 235, change: 0.00257025
# Epoch 236, change: 0.00256200
# Epoch 237, change: 0.00255380
# Epoch 238, change: 0.00254556
# Epoch 239, change: 0.00253749
# Epoch 240, change: 0.00252949
# Epoch 241, change: 0.00252147
# Epoch 242, change: 0.00251358
# Epoch 243, change: 0.00250565
# Epoch 244, change: 0.00249781
# Epoch 245, change: 0.00249004
# Epoch 246, change: 0.00248226
# Epoch 247, change: 0.00247472
# Epoch 248, change: 0.00246702
# Epoch 249, change: 0.00245946
# Epoch 250, change: 0.00245197
# Epoch 251, change: 0.00244448
# Epoch 252, change: 0.00243707
# Epoch 253, change: 0.00242972
# Epoch 254, change: 0.00242241
# Epoch 255, change: 0.00241511
# Epoch 256, change: 0.00240795
# Epoch 257, change: 0.00240075
# Epoch 258, change: 0.00239364
# Epoch 259, change: 0.00238660
# Epoch 260, change: 0.00237948
# Epoch 261, change: 0.00237248
# Epoch 262, change: 0.00236551
# Epoch 263, change: 0.00235862
# Epoch 264, change: 0.00235170
# Epoch 265, change: 0.00234502
# Epoch 266, change: 0.00233814
# Epoch 267, change: 0.00233139
# Epoch 268, change: 0.00232470
# Epoch 269, change: 0.00231804
# Epoch 270, change: 0.00231147
# Epoch 271, change: 0.00230487
# Epoch 272, change: 0.00229837
# Epoch 273, change: 0.00229180
# Epoch 274, change: 0.00228535
# Epoch 275, change: 0.00227888
# Epoch 276, change: 0.00227249
# Epoch 277, change: 0.00226614
# Epoch 278, change: 0.00225991
# Epoch 279, change: 0.00225356
# Epoch 280, change: 0.00224737
# Epoch 281, change: 0.00224109
# Epoch 282, change: 0.00223492
# Epoch 283, change: 0.00222888
# Epoch 284, change: 0.00222266
# Epoch 285, change: 0.00221667
# Epoch 286, change: 0.00221059
# Epoch 287, change: 0.00220458
# Epoch 288, change: 0.00219866
# Epoch 289, change: 0.00219264
# Epoch 290, change: 0.00218683
# Epoch 291, change: 0.00218087
# Epoch 292, change: 0.00217500
# Epoch 293, change: 0.00216929
# Epoch 294, change: 0.00216344
# Epoch 295, change: 0.00215768
# Epoch 296, change: 0.00215200
# Epoch 297, change: 0.00214631
# Epoch 298, change: 0.00214058
# Epoch 299, change: 0.00213500
# Epoch 300, change: 0.00212938
# Epoch 301, change: 0.00212382
# Epoch 302, change: 0.00211828
# Epoch 303, change: 0.00211279
# Epoch 304, change: 0.00210726
# Epoch 305, change: 0.00210181
# Epoch 306, change: 0.00209634
# Epoch 307, change: 0.00209096
# Epoch 308, change: 0.00208559
# Epoch 309, change: 0.00208017
# Epoch 310, change: 0.00207596
# Epoch 311, change: 0.00207187
# Epoch 312, change: 0.00206775
# Epoch 313, change: 0.00206363
# Epoch 314, change: 0.00205965
# Epoch 315, change: 0.00205556
# Epoch 316, change: 0.00205157
# Epoch 317, change: 0.00204753
# Epoch 318, change: 0.00204353
# Epoch 319, change: 0.00203964
# Epoch 320, change: 0.00203569
# Epoch 321, change: 0.00203175
# Epoch 322, change: 0.00202780
# Epoch 323, change: 0.00202394
# Epoch 324, change: 0.00202007
# Epoch 325, change: 0.00201625
# Epoch 326, change: 0.00201238
# Epoch 327, change: 0.00200857
# Epoch 328, change: 0.00200476
# Epoch 329, change: 0.00200105
# Epoch 330, change: 0.00199727
# Epoch 331, change: 0.00199353
# Epoch 332, change: 0.00198978
# Epoch 333, change: 0.00198605
# Epoch 334, change: 0.00198243
# Epoch 335, change: 0.00197872
# Epoch 336, change: 0.00197508
# Epoch 337, change: 0.00197140
# Epoch 338, change: 0.00196778
# Epoch 339, change: 0.00196416
# Epoch 340, change: 0.00196056
# Epoch 341, change: 0.00195699
# Epoch 342, change: 0.00195342
# Epoch 343, change: 0.00194987
# Epoch 344, change: 0.00194636
# Epoch 345, change: 0.00194283
# Epoch 346, change: 0.00193933
# Epoch 347, change: 0.00193585
# Epoch 348, change: 0.00193238
# Epoch 349, change: 0.00192894
# Epoch 350, change: 0.00192547
# Epoch 351, change: 0.00192201
# Epoch 352, change: 0.00191863
# Epoch 353, change: 0.00191521
# Epoch 354, change: 0.00191184
# Epoch 355, change: 0.00190847
# Epoch 356, change: 0.00190508
# Epoch 357, change: 0.00190177
# Epoch 358, change: 0.00189846
# Epoch 359, change: 0.00189513
# Epoch 360, change: 0.00189183
# Epoch 361, change: 0.00188848
# Epoch 362, change: 0.00188525
# Epoch 363, change: 0.00188196
# Epoch 364, change: 0.00187871
# Epoch 365, change: 0.00187546
# Epoch 366, change: 0.00187225
# Epoch 367, change: 0.00186904
# Epoch 368, change: 0.00186584
# Epoch 369, change: 0.00186263
# Epoch 370, change: 0.00185942
# Epoch 371, change: 0.00185629
# Epoch 372, change: 0.00185314
# Epoch 373, change: 0.00184996
# Epoch 374, change: 0.00184686
# Epoch 375, change: 0.00184377
# Epoch 376, change: 0.00184061
# Epoch 377, change: 0.00183756
# Epoch 378, change: 0.00183446
# Epoch 379, change: 0.00183137
# Epoch 380, change: 0.00182832
# Epoch 381, change: 0.00182529
# Epoch 382, change: 0.00182224
# Epoch 383, change: 0.00181917
# Epoch 384, change: 0.00181463
# Epoch 385, change: 0.00180909
# Epoch 386, change: 0.00180349
# Epoch 387, change: 0.00179801
# Epoch 388, change: 0.00179248
# Epoch 389, change: 0.00178701
# Epoch 390, change: 0.00178155
# Epoch 391, change: 0.00177616
# Epoch 392, change: 0.00177073
# Epoch 393, change: 0.00176542
# Epoch 394, change: 0.00176008
# Epoch 395, change: 0.00175480
# Epoch 396, change: 0.00174947
# Epoch 397, change: 0.00174425
# Epoch 398, change: 0.00173902
# Epoch 399, change: 0.00173384
# Epoch 400, change: 0.00172863
# Epoch 401, change: 0.00172351
# Epoch 402, change: 0.00171840
# Epoch 403, change: 0.00171329
# Epoch 404, change: 0.00170823
# Epoch 405, change: 0.00170318
# Epoch 406, change: 0.00169815
# Epoch 407, change: 0.00169317
# Epoch 408, change: 0.00168819
# Epoch 409, change: 0.00168324
# Epoch 410, change: 0.00167834
# Epoch 411, change: 0.00167343
# Epoch 412, change: 0.00166854
# Epoch 413, change: 0.00166371
# Epoch 414, change: 0.00165886
# Epoch 415, change: 0.00165407
# Epoch 416, change: 0.00164929
# Epoch 417, change: 0.00164452
# Epoch 418, change: 0.00163980
# Epoch 419, change: 0.00163510
# Epoch 420, change: 0.00163035
# Epoch 421, change: 0.00162573
# Epoch 422, change: 0.00162109
# Epoch 423, change: 0.00161647
# Epoch 424, change: 0.00161187
# Epoch 425, change: 0.00160727
# Epoch 426, change: 0.00160273
# Epoch 427, change: 0.00159817
# Epoch 428, change: 0.00159368
# Epoch 429, change: 0.00158917
# Epoch 430, change: 0.00158470
# Epoch 431, change: 0.00158028
# Epoch 432, change: 0.00157583
# Epoch 433, change: 0.00157143
# Epoch 434, change: 0.00156700
# Epoch 435, change: 0.00156265
# Epoch 436, change: 0.00155832
# Epoch 437, change: 0.00155397
# Epoch 438, change: 0.00154969
# Epoch 439, change: 0.00154538
# Epoch 440, change: 0.00154114
# Epoch 441, change: 0.00153681
# Epoch 442, change: 0.00153264
# Epoch 443, change: 0.00152842
# Epoch 444, change: 0.00152422
# Epoch 445, change: 0.00152006
# Epoch 446, change: 0.00151588
# Epoch 447, change: 0.00151175
# Epoch 448, change: 0.00150764
# Epoch 449, change: 0.00150356
# Epoch 450, change: 0.00149947
# Epoch 451, change: 0.00149540
# Epoch 452, change: 0.00149136
# Epoch 453, change: 0.00148736
# Epoch 454, change: 0.00148332
# Epoch 455, change: 0.00147935
# Epoch 456, change: 0.00147538
# Epoch 457, change: 0.00147141
# Epoch 458, change: 0.00146749
# Epoch 459, change: 0.00146355
# Epoch 460, change: 0.00145966
# Epoch 461, change: 0.00145576
# Epoch 462, change: 0.00145189
# Epoch 463, change: 0.00144804
# Epoch 464, change: 0.00144421
# Epoch 465, change: 0.00144035
# Epoch 466, change: 0.00143660
# Epoch 467, change: 0.00143278
# Epoch 468, change: 0.00142903
# Epoch 469, change: 0.00142527
# Epoch 470, change: 0.00142151
# Epoch 471, change: 0.00141781
# Epoch 472, change: 0.00141408
# Epoch 473, change: 0.00141043
# Epoch 474, change: 0.00140673
# Epoch 475, change: 0.00140308
# Epoch 476, change: 0.00139943
# Epoch 477, change: 0.00139583
# Epoch 478, change: 0.00139220
# Epoch 479, change: 0.00138860
# Epoch 480, change: 0.00138503
# Epoch 481, change: 0.00138146
# Epoch 482, change: 0.00137792
# Epoch 483, change: 0.00137438
# Epoch 484, change: 0.00137086
# Epoch 485, change: 0.00136736
# Epoch 486, change: 0.00136385
# Epoch 487, change: 0.00136038
# Epoch 488, change: 0.00135690
# Epoch 489, change: 0.00135347
# Epoch 490, change: 0.00135002
# Epoch 491, change: 0.00134660
# Epoch 492, change: 0.00134320
# Epoch 493, change: 0.00133980
# Epoch 494, change: 0.00133642
# Epoch 495, change: 0.00133304
# Epoch 496, change: 0.00132971
# Epoch 497, change: 0.00132637
# Epoch 498, change: 0.00132306
# Epoch 499, change: 0.00131972
# max_iter reached after 15 seconds
# Epoch 500, change: 0.00131645
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(max_iter=500, solver='saga', verbose=1)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy", train_accuracy)
print(f"Test Accuracy", test_accuracy)
# Out:
# Training Accuracy 0.7349535455663342
# Test Accuracy 0.7348430508590361
