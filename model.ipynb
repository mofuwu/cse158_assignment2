# %%
import json
from matplotlib import pyplot as plt
from collections import defaultdict
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import numpy
import random
import gzip
import math
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
from collections import Counter

# %%
f = gzip.open("cleaned_dataset.json.gz")
dataset = []
for l in f:
    dataset.append(json.loads(l))
dataset = dataset[0]

# %%
dataset[0]
# Out:
# {'fit': 'fit',
#  'bust size': '34d',
#  'item_id': '2260466',
#  'weight': 137,
#  'rating': 10,
#  'rented for': 'vacation',
#  'review_text': "An adorable romper! Belt and zipper were a little hard to navigate in a full day of wear/bathroom use, but that's to be expected. Wish it had pockets, but other than that-- absolutely perfect! I got a million compliments.",
#  'body type': 'hourglass',
#  'review_summary': 'So many compliments!',
#  'category': 'romper',
#  'height': 68,
#  'size': 14,
#  'age': 28,
#  'fit_numeric': 0}

# %%
import sklearn
from sklearn.model_selection import train_test_split

dataTrain, dataTest = train_test_split(dataset, test_size= 0.2, random_state=42)

print(len(dataTrain))
print(len(dataTest))
# Out:
# 117104
# 29277

# %%
# one hot encoding body type

unique_body_types = list(set(d['body type'] for d in dataTrain))
body_type_to_onehot = {bt: [1 if i == idx else 0 for i in range(len(unique_body_types))] for idx, bt in enumerate(unique_body_types)}

# %%
# using the frequency of each item id as input

item_id_counts = Counter(d['item_id'] for d in dataTrain)
total_items = sum(item_id_counts.values())

item_id_to_frequency = {item: count / total_items for item, count in item_id_counts.items()}

# %%
def feat1(datum):
    
    onehot_body_type = body_type_to_onehot.get(datum['body type'], [0]*len(unique_body_types))
    
    frequency_item_id = item_id_to_frequency.get(datum['item_id'], 0)
    
    height = datum['height']
    weight = datum['weight']
    size = datum['size']
    rating = datum['rating']
    
    return [1] + [height] + [weight] + [size] + [rating] + onehot_body_type + [frequency_item_id]

# %%
X_train = [feat1(d) for d in dataTrain]
y_train = [d['fit_numeric'] for d in dataTrain]

X_test = [feat1(d) for d in dataTest]
y_test = [d['fit_numeric'] for d in dataTest]

# %%
model = LogisticRegression(max_iter=500, solver = 'saga', verbose=1)
model.fit(X_train, y_train)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.03489088
# Epoch 3, change: 0.02831147
# Epoch 4, change: 0.02297447
# Epoch 5, change: 0.02201455
# Epoch 6, change: 0.01971145
# Epoch 7, change: 0.01794773
# Epoch 8, change: 0.01663935
# Epoch 9, change: 0.01548201
# Epoch 10, change: 0.01463996
# Epoch 11, change: 0.01424790
# Epoch 12, change: 0.01384801
# Epoch 13, change: 0.01345172
# Epoch 14, change: 0.01307661
# Epoch 15, change: 0.01270388
# Epoch 16, change: 0.01236714
# Epoch 17, change: 0.01202430
# Epoch 18, change: 0.01169219
# Epoch 19, change: 0.01136975
# Epoch 20, change: 0.01105546
# Epoch 21, change: 0.01075696
# Epoch 22, change: 0.01046483
# Epoch 23, change: 0.01017836
# Epoch 24, change: 0.00989310
# Epoch 25, change: 0.00963676
# Epoch 26, change: 0.00936554
# Epoch 27, change: 0.00911382
# Epoch 28, change: 0.00885507
# Epoch 29, change: 0.00861851
# Epoch 30, change: 0.00838846
# Epoch 31, change: 0.00815623
# Epoch 32, change: 0.00793965
# Epoch 33, change: 0.00772855
# Epoch 34, change: 0.00751044
# Epoch 35, change: 0.00731528
# Epoch 36, change: 0.00711263
# Epoch 37, change: 0.00691631
# Epoch 38, change: 0.00673217
# Epoch 39, change: 0.00654652
# Epoch 40, change: 0.00637179
# Epoch 41, change: 0.00620289
# Epoch 42, change: 0.00603041
# Epoch 43, change: 0.00586997
# Epoch 44, change: 0.00571270
# Epoch 45, change: 0.00555973
# Epoch 46, change: 0.00541147
# Epoch 47, change: 0.00526439
# Epoch 48, change: 0.00511634
# Epoch 49, change: 0.00497968
# Epoch 50, change: 0.00484529
# Epoch 51, change: 0.00471639
# Epoch 52, change: 0.00458899
# Epoch 53, change: 0.00446724
# Epoch 54, change: 0.00438864
# Epoch 55, change: 0.00437926
# Epoch 56, change: 0.00436988
# Epoch 57, change: 0.00436058
# Epoch 58, change: 0.00435153
# Epoch 59, change: 0.00434236
# Epoch 60, change: 0.00433329
# Epoch 61, change: 0.00432462
# Epoch 62, change: 0.00431542
# Epoch 63, change: 0.00430668
# Epoch 64, change: 0.00429798
# Epoch 65, change: 0.00428922
# Epoch 66, change: 0.00428074
# Epoch 67, change: 0.00427226
# Epoch 68, change: 0.00426358
# Epoch 69, change: 0.00425519
# Epoch 70, change: 0.00424696
# Epoch 71, change: 0.00423842
# Epoch 72, change: 0.00422997
# Epoch 73, change: 0.00422176
# Epoch 74, change: 0.00421387
# Epoch 75, change: 0.00420552
# Epoch 76, change: 0.00419743
# Epoch 77, change: 0.00418924
# Epoch 78, change: 0.00418128
# Epoch 79, change: 0.00417302
# Epoch 80, change: 0.00416526
# Epoch 81, change: 0.00415734
# Epoch 82, change: 0.00414930
# Epoch 83, change: 0.00414143
# Epoch 84, change: 0.00413363
# Epoch 85, change: 0.00412574
# Epoch 86, change: 0.00411810
# Epoch 87, change: 0.00410998
# Epoch 88, change: 0.00410253
# Epoch 89, change: 0.00409477
# Epoch 90, change: 0.00408705
# Epoch 91, change: 0.00407951
# Epoch 92, change: 0.00407162
# Epoch 93, change: 0.00406410
# Epoch 94, change: 0.00405664
# Epoch 95, change: 0.00404900
# Epoch 96, change: 0.00404155
# Epoch 97, change: 0.00403408
# Epoch 98, change: 0.00402653
# Epoch 99, change: 0.00401906
# Epoch 100, change: 0.00401164
# Epoch 101, change: 0.00400414
# Epoch 102, change: 0.00399684
# Epoch 103, change: 0.00398937
# Epoch 104, change: 0.00398217
# Epoch 105, change: 0.00397464
# Epoch 106, change: 0.00396726
# Epoch 107, change: 0.00395991
# Epoch 108, change: 0.00395273
# Epoch 109, change: 0.00394542
# Epoch 110, change: 0.00393814
# Epoch 111, change: 0.00393112
# Epoch 112, change: 0.00392372
# Epoch 113, change: 0.00391665
# Epoch 114, change: 0.00390941
# Epoch 115, change: 0.00390225
# Epoch 116, change: 0.00389518
# Epoch 117, change: 0.00388802
# Epoch 118, change: 0.00388094
# Epoch 119, change: 0.00387389
# Epoch 120, change: 0.00386677
# Epoch 121, change: 0.00385971
# Epoch 122, change: 0.00385263
# Epoch 123, change: 0.00384556
# Epoch 124, change: 0.00383857
# Epoch 125, change: 0.00383165
# Epoch 126, change: 0.00382466
# Epoch 127, change: 0.00381757
# Epoch 128, change: 0.00381076
# Epoch 129, change: 0.00380375
# Epoch 130, change: 0.00379681
# Epoch 131, change: 0.00378989
# Epoch 132, change: 0.00378309
# Epoch 133, change: 0.00377613
# Epoch 134, change: 0.00376928
# Epoch 135, change: 0.00376245
# Epoch 136, change: 0.00375554
# Epoch 137, change: 0.00374882
# Epoch 138, change: 0.00374193
# Epoch 139, change: 0.00373518
# Epoch 140, change: 0.00372838
# Epoch 141, change: 0.00372147
# Epoch 142, change: 0.00371480
# Epoch 143, change: 0.00370802
# Epoch 144, change: 0.00370133
# Epoch 145, change: 0.00369467
# Epoch 146, change: 0.00368791
# Epoch 147, change: 0.00368127
# Epoch 148, change: 0.00367448
# Epoch 149, change: 0.00366792
# Epoch 150, change: 0.00366128
# Epoch 151, change: 0.00365470
# Epoch 152, change: 0.00364799
# Epoch 153, change: 0.00364139
# Epoch 154, change: 0.00363470
# Epoch 155, change: 0.00362825
# Epoch 156, change: 0.00362170
# Epoch 157, change: 0.00361515
# Epoch 158, change: 0.00360867
# Epoch 159, change: 0.00360207
# Epoch 160, change: 0.00359547
# Epoch 161, change: 0.00358905
# Epoch 162, change: 0.00358252
# Epoch 163, change: 0.00357615
# Epoch 164, change: 0.00356970
# Epoch 165, change: 0.00356314
# Epoch 166, change: 0.00355661
# Epoch 167, change: 0.00355017
# Epoch 168, change: 0.00354390
# Epoch 169, change: 0.00353738
# Epoch 170, change: 0.00353110
# Epoch 171, change: 0.00352458
# Epoch 172, change: 0.00351835
# Epoch 173, change: 0.00351198
# Epoch 174, change: 0.00350563
# Epoch 175, change: 0.00349926
# Epoch 176, change: 0.00349288
# Epoch 177, change: 0.00348666
# Epoch 178, change: 0.00348043
# Epoch 179, change: 0.00347410
# Epoch 180, change: 0.00346783
# Epoch 181, change: 0.00346149
# Epoch 182, change: 0.00345526
# Epoch 183, change: 0.00344902
# Epoch 184, change: 0.00344283
# Epoch 185, change: 0.00343664
# Epoch 186, change: 0.00343039
# Epoch 187, change: 0.00342414
# Epoch 188, change: 0.00341807
# Epoch 189, change: 0.00341189
# Epoch 190, change: 0.00340571
# Epoch 191, change: 0.00339950
# Epoch 192, change: 0.00339341
# Epoch 193, change: 0.00338741
# Epoch 194, change: 0.00338119
# Epoch 195, change: 0.00337514
# Epoch 196, change: 0.00336908
# Epoch 197, change: 0.00336293
# Epoch 198, change: 0.00335690
# Epoch 199, change: 0.00335089
# Epoch 200, change: 0.00334477
# Epoch 201, change: 0.00333870
# Epoch 202, change: 0.00333266
# Epoch 203, change: 0.00332671
# Epoch 204, change: 0.00332075
# Epoch 205, change: 0.00331477
# Epoch 206, change: 0.00330873
# Epoch 207, change: 0.00330284
# Epoch 208, change: 0.00329677
# Epoch 209, change: 0.00329090
# Epoch 210, change: 0.00328500
# Epoch 211, change: 0.00327897
# Epoch 212, change: 0.00327319
# Epoch 213, change: 0.00326723
# Epoch 214, change: 0.00326137
# Epoch 215, change: 0.00325549
# Epoch 216, change: 0.00324970
# Epoch 217, change: 0.00324385
# Epoch 218, change: 0.00323798
# Epoch 219, change: 0.00323215
# Epoch 220, change: 0.00322626
# Epoch 221, change: 0.00322050
# Epoch 222, change: 0.00321472
# Epoch 223, change: 0.00320890
# Epoch 224, change: 0.00320305
# Epoch 225, change: 0.00319740
# Epoch 226, change: 0.00319160
# Epoch 227, change: 0.00318585
# Epoch 228, change: 0.00318010
# Epoch 229, change: 0.00317438
# Epoch 230, change: 0.00316868
# Epoch 231, change: 0.00316295
# Epoch 232, change: 0.00315720
# Epoch 233, change: 0.00315162
# Epoch 234, change: 0.00314589
# Epoch 235, change: 0.00314022
# Epoch 236, change: 0.00313471
# Epoch 237, change: 0.00312897
# Epoch 238, change: 0.00312328
# Epoch 239, change: 0.00311776
# Epoch 240, change: 0.00311209
# Epoch 241, change: 0.00310655
# Epoch 242, change: 0.00310082
# Epoch 243, change: 0.00309533
# Epoch 244, change: 0.00308975
# Epoch 245, change: 0.00308425
# Epoch 246, change: 0.00307869
# Epoch 247, change: 0.00307303
# Epoch 248, change: 0.00306758
# Epoch 249, change: 0.00306205
# Epoch 250, change: 0.00305657
# Epoch 251, change: 0.00305103
# Epoch 252, change: 0.00304566
# Epoch 253, change: 0.00304005
# Epoch 254, change: 0.00303467
# Epoch 255, change: 0.00302913
# Epoch 256, change: 0.00302371
# Epoch 257, change: 0.00301831
# Epoch 258, change: 0.00301281
# Epoch 259, change: 0.00299840
# Epoch 260, change: 0.00298422
# Epoch 261, change: 0.00297017
# Epoch 262, change: 0.00295613
# Epoch 263, change: 0.00294220
# Epoch 264, change: 0.00292839
# Epoch 265, change: 0.00291468
# Epoch 266, change: 0.00290113
# Epoch 267, change: 0.00288765
# Epoch 268, change: 0.00287428
# Epoch 269, change: 0.00286087
# Epoch 270, change: 0.00284776
# Epoch 271, change: 0.00283471
# Epoch 272, change: 0.00282164
# Epoch 273, change: 0.00280876
# Epoch 274, change: 0.00279596
# Epoch 275, change: 0.00278328
# Epoch 276, change: 0.00277068
# Epoch 277, change: 0.00275806
# Epoch 278, change: 0.00274563
# Epoch 279, change: 0.00273331
# Epoch 280, change: 0.00272106
# Epoch 281, change: 0.00270892
# Epoch 282, change: 0.00269692
# Epoch 283, change: 0.00268480
# Epoch 284, change: 0.00267298
# Epoch 285, change: 0.00266107
# Epoch 286, change: 0.00264938
# Epoch 287, change: 0.00263770
# Epoch 288, change: 0.00262612
# Epoch 289, change: 0.00261464
# Epoch 290, change: 0.00260313
# Epoch 291, change: 0.00259192
# Epoch 292, change: 0.00258062
# Epoch 293, change: 0.00256946
# Epoch 294, change: 0.00255831
# Epoch 295, change: 0.00254728
# Epoch 296, change: 0.00253630
# Epoch 297, change: 0.00252553
# Epoch 298, change: 0.00251463
# Epoch 299, change: 0.00250392
# Epoch 300, change: 0.00249328
# Epoch 301, change: 0.00248267
# Epoch 302, change: 0.00247218
# Epoch 303, change: 0.00246179
# Epoch 304, change: 0.00245143
# Epoch 305, change: 0.00244109
# Epoch 306, change: 0.00243082
# Epoch 307, change: 0.00242063
# Epoch 308, change: 0.00241055
# Epoch 309, change: 0.00240051
# Epoch 310, change: 0.00239048
# Epoch 311, change: 0.00238062
# Epoch 312, change: 0.00237076
# Epoch 313, change: 0.00236104
# Epoch 314, change: 0.00235124
# Epoch 315, change: 0.00234160
# Epoch 316, change: 0.00233207
# Epoch 317, change: 0.00232244
# Epoch 318, change: 0.00231304
# Epoch 319, change: 0.00230369
# Epoch 320, change: 0.00229436
# Epoch 321, change: 0.00228498
# Epoch 322, change: 0.00227573
# Epoch 323, change: 0.00226660
# Epoch 324, change: 0.00225748
# Epoch 325, change: 0.00224844
# Epoch 326, change: 0.00223943
# Epoch 327, change: 0.00223048
# Epoch 328, change: 0.00222160
# Epoch 329, change: 0.00221280
# Epoch 330, change: 0.00220400
# Epoch 331, change: 0.00219524
# Epoch 332, change: 0.00218661
# Epoch 333, change: 0.00217798
# Epoch 334, change: 0.00216938
# Epoch 335, change: 0.00216091
# Epoch 336, change: 0.00215241
# Epoch 337, change: 0.00214401
# Epoch 338, change: 0.00213566
# Epoch 339, change: 0.00212737
# Epoch 340, change: 0.00211911
# Epoch 341, change: 0.00211088
# Epoch 342, change: 0.00210272
# Epoch 343, change: 0.00209461
# Epoch 344, change: 0.00208652
# Epoch 345, change: 0.00207852
# Epoch 346, change: 0.00207052
# Epoch 347, change: 0.00206256
# Epoch 348, change: 0.00205472
# Epoch 349, change: 0.00204689
# Epoch 350, change: 0.00203913
# Epoch 351, change: 0.00203133
# Epoch 352, change: 0.00202370
# Epoch 353, change: 0.00201610
# Epoch 354, change: 0.00200839
# Epoch 355, change: 0.00200089
# Epoch 356, change: 0.00199336
# Epoch 357, change: 0.00198586
# Epoch 358, change: 0.00197847
# Epoch 359, change: 0.00197105
# Epoch 360, change: 0.00196374
# Epoch 361, change: 0.00195638
# Epoch 362, change: 0.00194911
# Epoch 363, change: 0.00194195
# Epoch 364, change: 0.00193470
# Epoch 365, change: 0.00192760
# Epoch 366, change: 0.00192053
# Epoch 367, change: 0.00191341
# Epoch 368, change: 0.00190639
# Epoch 369, change: 0.00189937
# Epoch 370, change: 0.00189250
# Epoch 371, change: 0.00188555
# Epoch 372, change: 0.00187871
# Epoch 373, change: 0.00187186
# Epoch 374, change: 0.00186511
# Epoch 375, change: 0.00185827
# Epoch 376, change: 0.00185157
# Epoch 377, change: 0.00184484
# Epoch 378, change: 0.00183827
# Epoch 379, change: 0.00183162
# Epoch 380, change: 0.00182504
# Epoch 381, change: 0.00181858
# Epoch 382, change: 0.00181204
# Epoch 383, change: 0.00180556
# Epoch 384, change: 0.00179912
# Epoch 385, change: 0.00179275
# Epoch 386, change: 0.00178634
# Epoch 387, change: 0.00177999
# Epoch 388, change: 0.00177376
# Epoch 389, change: 0.00176740
# Epoch 390, change: 0.00176122
# Epoch 391, change: 0.00175499
# Epoch 392, change: 0.00174885
# Epoch 393, change: 0.00174271
# Epoch 394, change: 0.00173658
# Epoch 395, change: 0.00173052
# Epoch 396, change: 0.00172449
# Epoch 397, change: 0.00171848
# Epoch 398, change: 0.00171249
# Epoch 399, change: 0.00170654
# Epoch 400, change: 0.00170069
# Epoch 401, change: 0.00169479
# Epoch 402, change: 0.00168892
# Epoch 403, change: 0.00168307
# Epoch 404, change: 0.00167726
# Epoch 405, change: 0.00167154
# Epoch 406, change: 0.00166578
# Epoch 407, change: 0.00166011
# Epoch 408, change: 0.00165444
# Epoch 409, change: 0.00164878
# Epoch 410, change: 0.00164318
# Epoch 411, change: 0.00163759
# Epoch 412, change: 0.00163200
# Epoch 413, change: 0.00162643
# Epoch 414, change: 0.00162092
# Epoch 415, change: 0.00161548
# Epoch 416, change: 0.00161005
# Epoch 417, change: 0.00160458
# Epoch 418, change: 0.00159917
# Epoch 419, change: 0.00159382
# Epoch 420, change: 0.00158847
# Epoch 421, change: 0.00158314
# Epoch 422, change: 0.00157785
# Epoch 423, change: 0.00157259
# Epoch 424, change: 0.00156736
# Epoch 425, change: 0.00156210
# Epoch 426, change: 0.00155697
# Epoch 427, change: 0.00155175
# Epoch 428, change: 0.00154659
# Epoch 429, change: 0.00154153
# Epoch 430, change: 0.00153641
# Epoch 431, change: 0.00153138
# Epoch 432, change: 0.00152631
# Epoch 433, change: 0.00152131
# Epoch 434, change: 0.00151629
# Epoch 435, change: 0.00151137
# Epoch 436, change: 0.00150642
# Epoch 437, change: 0.00150146
# Epoch 438, change: 0.00149659
# Epoch 439, change: 0.00149172
# Epoch 440, change: 0.00148681
# Epoch 441, change: 0.00148198
# Epoch 442, change: 0.00147718
# Epoch 443, change: 0.00147246
# Epoch 444, change: 0.00146765
# Epoch 445, change: 0.00146293
# Epoch 446, change: 0.00145818
# Epoch 447, change: 0.00145351
# Epoch 448, change: 0.00144881
# Epoch 449, change: 0.00144418
# Epoch 450, change: 0.00143955
# Epoch 451, change: 0.00143491
# Epoch 452, change: 0.00143035
# Epoch 453, change: 0.00142575
# Epoch 454, change: 0.00142128
# Epoch 455, change: 0.00141670
# Epoch 456, change: 0.00141222
# Epoch 457, change: 0.00140771
# Epoch 458, change: 0.00140325
# Epoch 459, change: 0.00139882
# Epoch 460, change: 0.00139435
# Epoch 461, change: 0.00139000
# Epoch 462, change: 0.00138561
# Epoch 463, change: 0.00138127
# Epoch 464, change: 0.00137691
# Epoch 465, change: 0.00137259
# Epoch 466, change: 0.00136827
# Epoch 467, change: 0.00136396
# Epoch 468, change: 0.00135970
# Epoch 469, change: 0.00135549
# Epoch 470, change: 0.00135124
# Epoch 471, change: 0.00134701
# Epoch 472, change: 0.00134287
# Epoch 473, change: 0.00133869
# Epoch 474, change: 0.00133449
# Epoch 475, change: 0.00133040
# Epoch 476, change: 0.00132628
# Epoch 477, change: 0.00132219
# Epoch 478, change: 0.00131809
# Epoch 479, change: 0.00131405
# Epoch 480, change: 0.00130998
# Epoch 481, change: 0.00130597
# Epoch 482, change: 0.00130195
# Epoch 483, change: 0.00129795
# Epoch 484, change: 0.00129396
# Epoch 485, change: 0.00129006
# Epoch 486, change: 0.00128610
# Epoch 487, change: 0.00128220
# Epoch 488, change: 0.00127823
# Epoch 489, change: 0.00127437
# Epoch 490, change: 0.00127049
# Epoch 491, change: 0.00126663
# Epoch 492, change: 0.00126281
# Epoch 493, change: 0.00125901
# Epoch 494, change: 0.00125515
# Epoch 495, change: 0.00125138
# Epoch 496, change: 0.00124762
# Epoch 497, change: 0.00124385
# Epoch 498, change: 0.00124014
# Epoch 499, change: 0.00123641
# max_iter reached after 15 seconds
# Epoch 500, change: 0.00123268
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(max_iter=500, solver='saga', verbose=1)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print(f"Training Accuracy", train_accuracy)
print(f"Test Accuracy", test_accuracy)
# Out:
# Training Accuracy 0.7358587238693811
# Test Accuracy 0.7357311199918024
